# %% [markdown]
# # PRIMER NOTEBOOK

# %% [markdown]
# ### Este es mi primer notebook y voy a hacer lo siguiente

# %% [markdown]
# Una lista **enumerada**
# 1. Primero
# 2. Segundo
# 3. Tercero

# %% [markdown]
# Una lista **por puntos**
# - Primero
# - Segundo
# - Tercero

# %% [markdown]
# Mi primer codigo

# %%
mi_primera_frase = "hola mundo"

# %%
# Como cuando lo ejecuto no sale nada, tengo que usar la funcion print()
print(mi_primera_frase)
# Out:
# hola mundo

# %%
# A ver si asi lo entiendes mejor:
numeros = (10,20,30,40,50)

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# ### Finalizamos con una bonita imagen

# %% [markdown]
# ![meme](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia2.dev.to%2Fdynamic%2Fimage%2Fwidth%3D800%252Cheight%3D%252Cfit%3Dscale-down%252Cgravity%3Dauto%252Cformat%3Dauto%2Fhttps%3A%2F%2Fdev-to-uploads.s3.amazonaws.com%2Fuploads%2Farticles%2Fc7cziks7c4dezyz8lkqs.png&f=1&nofb=1&ipt=1ab742f4e343dbeb6cdbf318be12ffbe75f5205cd9edaf82dcd67e7c39d2b170)
